# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('P:\AI-Resume-Screener\data\dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10174 entries, 0 to 10173
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10174 non-null  str
#  1   Name                 10174 non-null  str
#  2   Role                 10174 non-null  str
#  3   Transcript           10174 non-null  str
#  4   Resume               10174 non-null  str
#  5   decision             10174 non-null  str
#  6   Reason_for_decision  10174 non-null  str
#  7   Job_Description      10174 non-null  str
# dtypes: str(8)
# memory usage: 636.0 KB

# %%
df.isnull().sum()
# Out:
# ID                     0
# Name                   0
# Role                   0
# Transcript             0
# Resume                 0
# decision               0
# Reason_for_decision    0
# Job_Description        0
# dtype: int64

# %%
df['Role'].value_counts()
# Out:
# Role
# Data Scientist                  538
# Software Engineer               480
# Product Manager                 458
# Data Engineer                   447
# UI Engineer                     375
# Data Analyst                    329
# software engineer               307
# data engineer                   307
# product manager                 303
# data scientist                  287
# E-commerce Specialist           268
# DevOps Engineer                 266
# Machine Learning Engineer       265
# Human Resources Specialist      262
# Digital Marketing Specialist    260
# Robotics Engineer               257
# Cloud Architect                 254
# QA Engineer                     251
# Blockchain Developer            251
# Mobile App Developer            247
# Full Stack Developer            246
# Database Administrator          243
# Cloud Engineer                  240
# Game Developer                  239
# Content Writer                  238
# AR/VR Developer                 237
# ...

# %%
df=df.drop(['ID','Name','Reason_for_decision','Transcript'],axis=1)

# %%
df.head
# Out:
# <bound method NDFrame.head of                              Role  \
# 0           E-commerce Specialist
# 1                  Game Developer
# 2      Human Resources Specialist
# 3           E-commerce Specialist
# 4           E-commerce Specialist
# ...                           ...
# 10169             Product Manager
# 10170                 UI Engineer
# 10171                 UI Engineer
# 10172               Data Engineer
# 10173             Product Manager
#
#                                                   Resume decision  \
# 0      Here's a professional resume for Jason Jones:\...   reject
# 1      Here's a professional resume for Ann Marshall:...   select
# 2      Here's a professional resume for Patrick Mccla...   reject
# 3      Here's a professional resume for Patricia Gray...   select
# 4      Here's a professional resume for Amanda Gross:...   reject
# ...                                                  ...      ...
# ...

# %%
categories=df['Role'].value_counts().reset_index()
categories
# Out:
#                             Role  count
# 0                 Data Scientist    538
# 1              Software Engineer    480
# 2                Product Manager    458
# 3                  Data Engineer    447
# 4                    UI Engineer    375
# 5                   Data Analyst    329
# 6              software engineer    307
# 7                  data engineer    307
# 8                product manager    303
# 9                 data scientist    287
# 10         E-commerce Specialist    268
# 11               DevOps Engineer    266
# 12     Machine Learning Engineer    265
# 13    Human Resources Specialist    262
# 14  Digital Marketing Specialist    260
# 15             Robotics Engineer    257
# 16               Cloud Architect    254
# 17                   QA Engineer    251
# 18          Blockchain Developer    251
# 19          Mobile App Developer    247
# 20          Full Stack Developer    246
# 21        Database Administrator    243
# ...

# %%
plt.figure(figsize=(12,8))
sns.barplot(y=categories['Role'], x=categories['count'], palette='cool')
plt.show()
# Out:
# C:\Users\Jay\AppData\Local\Temp\ipykernel_13556\791903398.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=categories['Role'], x=categories['count'], palette='cool')

# %%
df.to_csv('P:\AI-Resume-Screener\data\dataset_cleaned.csv',index=False)
